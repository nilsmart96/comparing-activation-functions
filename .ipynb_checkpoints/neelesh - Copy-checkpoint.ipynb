# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from livelossplot import PlotLossesKeras
# import keras models
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten
from keras.utils import np_utils

# %%
# set random seed globally
my_seed = 21
from numpy.random import seed
seed(my_seed)
import tensorflow as tf
tf.random.set_seed(my_seed) 
# tensorflow version
print(tf.__version__)
# Out:
# 2.6.0

# %%
df = pd.read_csv('1_Datasets/Maternal_Health_Risk_Data_Set.csv',
                 )
df
# Out:
#       Age  SystolicBP  DiastolicBP    BS  BodyTemp  HeartRate  RiskLevel
# 0      25         130           80  15.0      98.0         86  high risk
# 1      35         140           90  13.0      98.0         70  high risk
# 2      29          90           70   8.0     100.0         80  high risk
# 3      30         140           85   7.0      98.0         70  high risk
# 4      35         120           60   6.1      98.0         76   low risk
# ...   ...         ...          ...   ...       ...        ...        ...
# 1009   22         120           60  15.0      98.0         80  high risk
# 1010   55         120           90  18.0      98.0         60  high risk
# 1011   35          85           60  19.0      98.0         86  high risk
# 1012   43         120           90  18.0      98.0         70  high risk
# 1013   32         120           65   6.0     101.0         76   mid risk
#
# [1014 rows x 7 columns]

# %%
# encoding the target column
le = LabelEncoder()
label = le.fit_transform(df['RiskLevel'])
label

encoded_df = df.copy()
encoded_df.drop("RiskLevel", axis=1, inplace=True)
encoded_df["RiskLevel"] = label
encoded_df
# Out:
#       Age  SystolicBP  DiastolicBP    BS  BodyTemp  HeartRate  RiskLevel
# 0      25         130           80  15.0      98.0         86          0
# 1      35         140           90  13.0      98.0         70          0
# 2      29          90           70   8.0     100.0         80          0
# 3      30         140           85   7.0      98.0         70          0
# 4      35         120           60   6.1      98.0         76          1
# ...   ...         ...          ...   ...       ...        ...        ...
# 1009   22         120           60  15.0      98.0         80          0
# 1010   55         120           90  18.0      98.0         60          0
# 1011   35          85           60  19.0      98.0         86          0
# 1012   43         120           90  18.0      98.0         70          0
# 1013   32         120           65   6.0     101.0         76          2
#
# [1014 rows x 7 columns]

# %%
# Set the total number of classes
nb_classes = len(encoded_df['RiskLevel'].unique())

# Creating target and features
X = encoded_df.drop(['RiskLevel'], axis=1)
y = encoded_df['RiskLevel']

# scale the variables
sc = StandardScaler() 
X_scaled = sc.fit_transform(X)

# Split into train and test set and normalize data
X_train, X_test, y_train, y_test = train_test_split(X_scaled,y, test_size = 0.2,stratify=y) #, random_state = 0)

print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (811, 6)
# (811,)
# (203, 6)
# (203,)

# %%
def buildSequentialModel():
    # Build a Sequential Model.
    model = Sequential()
    # model.add(Flatten(input_shape=(28, 28)))
    
    
    model.add(Dense(100, kernel_initializer='normal', activation='tanh'))
    model.add(Dropout(0.3))
    model.add(Dense(80, kernel_initializer='normal', activation='tanh'))
    model.add(Dropout(0.3))
    model.add(Dense(60, kernel_initializer='normal', activation='tanh'))
    model.add(Dropout(0.3))
    
    # Output Layer
    model.add(Dense(nb_classes, activation='softmax'))
   
    return model

# %% [markdown]
# Conventional Activation Functions to test
# - Logistic regression hypothesis (Sigmoid)
# - Hyperbolic Tangent (tanh) # rescaled sigmoid to (-1, +1)
# - Rectified Linear Unit (ReLU)
# - Gaussian Error Linear Unit (GELU) # smoothed ReLU
# - Normalized Exponential Function (Softmax)

# %%
# instantiate model
model = buildSequentialModel()
# compile model
#model.compile(loss='categorical_crossentropy', optimizer='adam')
model.compile(optimizer=keras.optimizers.Adam(learning_rate=0.001),
                loss=keras.losses.SparseCategoricalCrossentropy(),
                metrics=['accuracy'])

# %%
model.fit(X_train, y_train,
          batch_size=100, epochs=50, verbose=1,
          validation_data=(X_test, y_test))
# Out:
# Epoch 1/50
# 9/9 [==============================] - 0s 17ms/step - loss: 1.0398 - accuracy: 0.5536 - val_loss: 0.9626 - val_accuracy: 0.5961
# Epoch 2/50
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9051 - accuracy: 0.6030 - val_loss: 0.8561 - val_accuracy: 0.5665
# Epoch 3/50
# 9/9 [==============================] - 0s 5ms/step - loss: 0.8201 - accuracy: 0.6141 - val_loss: 0.8395 - val_accuracy: 0.5616
# Epoch 4/50
# 9/9 [==============================] - 0s 5ms/step - loss: 0.7965 - accuracy: 0.6202 - val_loss: 0.8399 - val_accuracy: 0.5665
# Epoch 5/50
# 9/9 [==============================] - 0s 5ms/step - loss: 0.7898 - accuracy: 0.6276 - val_loss: 0.8302 - val_accuracy: 0.5862
# Epoch 6/50
# 9/9 [==============================] - 0s 5ms/step - loss: 0.7851 - accuracy: 0.6498 - val_loss: 0.8202 - val_accuracy: 0.6305
# Epoch 7/50
# 9/9 [==============================] - 0s 5ms/step - loss: 0.7848 - accuracy: 0.6547 - val_loss: 0.8268 - val_accuracy: 0.6256
# Epoch 8/50
# 9/9 [==============================] - 0s 5ms/step - loss: 0.7770 - accuracy: 0.6510 - val_loss: 0.8159 - val_accuracy: 0.6108
# Epoch 9/50
# 9/9 [==============================] - 0s 5ms/step - loss: 0.7799 - accuracy: 0.6486 - val_loss: 0.8251 - val_accuracy: 0.6010
# Epoch 10/50
# 9/9 [==============================] - 0s 5ms/step - loss: 0.7870 - accuracy: 0.6338 - val_loss: 0.8194 - val_accuracy: 0.6158
# Epoch 11/50
# 9/9 [==============================] - 0s 5ms/step - loss: 0.7827 - accuracy: 0.6424 - val_loss: 0.8106 - val_accuracy: 0.6010
# Epoch 12/50
# 9/9 [==============================] - 0s 5ms/step - loss: 0.7778 - accuracy: 0.6436 - val_loss: 0.8106 - val_accuracy: 0.6108
# Epoch 13/50
# 9/9 [==============================] - 0s 5ms/step - loss: 0.7716 - accuracy: 0.6436 - val_loss: 0.8116 - val_accuracy: 0.6158
# Epoch 14/50
# 9/9 [==============================] - 0s 6ms/step - loss: 0.7700 - accuracy: 0.6363 - val_loss: 0.8267 - val_accuracy: 0.6108
# Epoch 15/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.7891 - accuracy: 0.6461 - val_loss: 0.8270 - val_accuracy: 0.6059
# Epoch 16/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.7745 - accuracy: 0.6461 - val_loss: 0.8178 - val_accuracy: 0.6256
# Epoch 17/50
# 9/9 [==============================] - 0s 5ms/step - loss: 0.7713 - accuracy: 0.6436 - val_loss: 0.8206 - val_accuracy: 0.6256
# Epoch 18/50
# 9/9 [==============================] - 0s 5ms/step - loss: 0.7736 - accuracy: 0.6326 - val_loss: 0.8185 - val_accuracy: 0.6355
# Epoch 19/50
# 9/9 [==============================] - 0s 5ms/step - loss: 0.7777 - accuracy: 0.6449 - val_loss: 0.8117 - val_accuracy: 0.6207
# Epoch 20/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.7711 - accuracy: 0.6350 - val_loss: 0.8115 - val_accuracy: 0.6207
# Epoch 21/50
# 9/9 [==============================] - 0s 5ms/step - loss: 0.7774 - accuracy: 0.6375 - val_loss: 0.8090 - val_accuracy: 0.6207
# Epoch 22/50
# 9/9 [==============================] - 0s 5ms/step - loss: 0.7736 - accuracy: 0.6473 - val_loss: 0.8060 - val_accuracy: 0.6158
# Epoch 23/50
# 9/9 [==============================] - 0s 5ms/step - loss: 0.7734 - accuracy: 0.6424 - val_loss: 0.8070 - val_accuracy: 0.6158
# Epoch 24/50
# 9/9 [==============================] - 0s 5ms/step - loss: 0.7766 - accuracy: 0.6510 - val_loss: 0.8063 - val_accuracy: 0.6158
# Epoch 25/50
# 9/9 [==============================] - 0s 5ms/step - loss: 0.7824 - accuracy: 0.6227 - val_loss: 0.8016 - val_accuracy: 0.6453
# Epoch 26/50
# 9/9 [==============================] - 0s 5ms/step - loss: 0.7781 - accuracy: 0.6313 - val_loss: 0.8007 - val_accuracy: 0.6305
# Epoch 27/50
# 9/9 [==============================] - 0s 5ms/step - loss: 0.7762 - accuracy: 0.6375 - val_loss: 0.8043 - val_accuracy: 0.6158
# Epoch 28/50
# 9/9 [==============================] - 0s 5ms/step - loss: 0.7813 - accuracy: 0.6289 - val_loss: 0.8100 - val_accuracy: 0.6158
# Epoch 29/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.7697 - accuracy: 0.6338 - val_loss: 0.8040 - val_accuracy: 0.6256
# Epoch 30/50
# 9/9 [==============================] - 0s 5ms/step - loss: 0.7747 - accuracy: 0.6350 - val_loss: 0.8015 - val_accuracy: 0.6256
# Epoch 31/50
# 9/9 [==============================] - 0s 5ms/step - loss: 0.7581 - accuracy: 0.6313 - val_loss: 0.8042 - val_accuracy: 0.6010
# Epoch 32/50
# 9/9 [==============================] - 0s 5ms/step - loss: 0.7775 - accuracy: 0.6165 - val_loss: 0.8106 - val_accuracy: 0.6059
# Epoch 33/50
# 9/9 [==============================] - 0s 5ms/step - loss: 0.7770 - accuracy: 0.6252 - val_loss: 0.8138 - val_accuracy: 0.6207
# Epoch 34/50
# 9/9 [==============================] - 0s 5ms/step - loss: 0.7780 - accuracy: 0.6350 - val_loss: 0.8223 - val_accuracy: 0.6305
# Epoch 35/50
# 9/9 [==============================] - 0s 5ms/step - loss: 0.7718 - accuracy: 0.6412 - val_loss: 0.8124 - val_accuracy: 0.6108
# Epoch 36/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.7716 - accuracy: 0.6523 - val_loss: 0.7994 - val_accuracy: 0.6404
# Epoch 37/50
# 9/9 [==============================] - 0s 5ms/step - loss: 0.7688 - accuracy: 0.6535 - val_loss: 0.7999 - val_accuracy: 0.6256
# Epoch 38/50
# 9/9 [==============================] - 0s 5ms/step - loss: 0.7671 - accuracy: 0.6621 - val_loss: 0.8080 - val_accuracy: 0.6404
# Epoch 39/50
# 9/9 [==============================] - 0s 5ms/step - loss: 0.7753 - accuracy: 0.6597 - val_loss: 0.8141 - val_accuracy: 0.6256
# Epoch 40/50
# 9/9 [==============================] - 0s 5ms/step - loss: 0.7678 - accuracy: 0.6289 - val_loss: 0.8145 - val_accuracy: 0.6256
# Epoch 41/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.7672 - accuracy: 0.6375 - val_loss: 0.8126 - val_accuracy: 0.6059
# Epoch 42/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.7786 - accuracy: 0.6350 - val_loss: 0.8061 - val_accuracy: 0.6010
# Epoch 43/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.7661 - accuracy: 0.6387 - val_loss: 0.8009 - val_accuracy: 0.6355
# Epoch 44/50
# 9/9 [==============================] - 0s 5ms/step - loss: 0.7735 - accuracy: 0.6461 - val_loss: 0.8023 - val_accuracy: 0.6256
# Epoch 45/50
# 9/9 [==============================] - 0s 5ms/step - loss: 0.7820 - accuracy: 0.6400 - val_loss: 0.8082 - val_accuracy: 0.6256
# Epoch 46/50
# 9/9 [==============================] - 0s 5ms/step - loss: 0.7730 - accuracy: 0.6523 - val_loss: 0.8090 - val_accuracy: 0.6207
# Epoch 47/50
# 9/9 [==============================] - 0s 5ms/step - loss: 0.7843 - accuracy: 0.6461 - val_loss: 0.8029 - val_accuracy: 0.6355
# Epoch 48/50
# 9/9 [==============================] - 0s 5ms/step - loss: 0.7825 - accuracy: 0.6498 - val_loss: 0.8061 - val_accuracy: 0.6158
# Epoch 49/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.7732 - accuracy: 0.6584 - val_loss: 0.8046 - val_accuracy: 0.6404
# Epoch 50/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.7765 - accuracy: 0.6621 - val_loss: 0.8047 - val_accuracy: 0.6305

# %%
#scores = model.evaluate(X_test, Y_test, verbose=0)
score = model.evaluate(X_test, y_test, verbose=1)
print('Your CV accuracy score is:', score[1])
# Out:
# 7/7 [==============================] - 0s 2ms/step - loss: 0.8047 - accuracy: 0.6305
# Your CV accuracy score is: 0.6305418610572815

# %%
# The predict_classes function outputs the highest probability class
# according to the trained classifier for each input example.
predicted_classes = np.argmax(model.predict(X_test), axis=-1)


# Identify which examples were correctly and incorrectly classified.
#correct_indices = np.nonzero(predicted_classes == y_test)[0]
#incorrect_indices = np.nonzero(predicted_classes != y_test)[0]

correct_indices = np.nonzero(predicted_classes == y_test.values)[0]
incorrect_indices = np.nonzero(predicted_classes != y_test.values)[0]


# Count the number of incorrectly classified examples of the considered test cases
len(incorrect_indices)
print("Your classifier got the following " + str(len(incorrect_indices)) + " items wrong out of " + str(X_test.shape[0]) + ":")
print(incorrect_indices)
# Out:
# Your classifier got the following 75 items wrong out of 203:
# [  0   7   8   9  12  14  16  18  19  21  25  28  29  30  33  37  38  43
#   44  45  48  51  53  57  60  61  62  63  66  67  71  73  75  76  77  78
#   81  83  85  87  92  94  97 102 104 106 108 109 115 121 122 124 126 130
#  131 135 137 138 142 144 146 150 152 164 167 168 170 175 180 186 188 191
#  193 197 199]

# %%
import sklearn
sklearn.metrics.confusion_matrix(y_test, predicted_classes, labels=None, sample_weight=None, normalize=None)
# Out:
# array([[39,  6, 10],
#        [ 4, 70,  7],
#        [11, 37, 19]], dtype=int64)
